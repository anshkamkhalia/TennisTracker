# %%
import numpy as np

# %%
X = np.load("processed_data/1_X.npy")
y = np.load("processed_data/1_y.npy")

# %%
X
# Out:
# array([[[-4.11222632e+00, -1.59423457e+00, -1.97634553e+00, ...,
#          -5.90629353e-01, -2.44905872e+00, -7.17744205e+00],
#         [-4.11222632e+00, -1.59423457e+00, -1.97634553e+00, ...,
#          -5.90629353e-01, -2.44905872e+00, -7.17744205e+00],
#         [-4.11222632e+00, -1.59423457e+00, -1.97634553e+00, ...,
#          -5.90629353e-01, -2.44905872e+00, -7.17744205e+00],
#         ...,
#         [-4.11222632e+00, -1.59423457e+00, -1.97634553e+00, ...,
#          -5.90629353e-01,  2.01805726e-01,  4.56030772e-01],
#         [-4.11222632e+00, -1.59423457e+00, -1.97634553e+00, ...,
#          -4.36781188e-01,  1.85235506e-01,  5.28406192e-01],
#         [-1.54803456e-01, -1.11417886e+00, -1.33944059e+00, ...,
#          -2.02683491e-01,  1.74087728e-01,  7.51945903e-01]],
#
#        [[-4.11222632e+00, -1.59423457e+00, -1.97634553e+00, ...,
#          -4.36781188e-01,  1.85235506e-01,  5.28406192e-01],
#         [-1.54803456e-01, -1.11417886e+00, -1.33944059e+00, ...,
# ...

# %%
y.mean()
# Out:
# 0.06272617611580217

# %%
np.count_nonzero(y)
# Out:
# 52

# %%
len(y) - np.count_nonzero(y)
# Out:
# 777

# %%
X.shape
# Out:
# (829, 15, 10)
