# %%
import numpy as np

# %%
X = np.load("processed_data/4_X.npy")
y = np.load("processed_data/1_y.npy")
X.shape
# Out:
# (1354, 15, 18)

# %%
print(np.min(X))
print(np.max(X))
# Out:
# -21.97852960339339
# 20.131699133201035
