# %%
import cv2 as cv
import numpy as np

# %%
cap = cv.VideoCapture("processed_videoplayback5.mp4")
# Out:
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x89fc05680] moov atom not found
# OpenCV: Couldn't read video stream from file "processed_videoplayback5.mp4"

# %%
print(cap.isOpened())
# Out:
# False
